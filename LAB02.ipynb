# %%
import simpy
import random
import numpy
import pandas as pd

env = simpy.Environment()

cashier_count = 10
barista_count = 20
customer_count = 1000
shop_uptime = 15 * 60

cashier = simpy.Resource(env, capacity=cashier_count)
barista = simpy.Resource(env, capacity=barista_count)

menu = {
    1: ["Regular Coffee", 10, 15],
    2: ["Latte", 30, 45],
    3: ["Mocha", 30, 45],
    4: ["Cold Brew", 10, 20],
    5: ["Frappe", 50, 70],
    6: ["Espresso", 20, 35],
    7: ["Coffee of the Day", 60, 80]
}

payment_options = {
    1: ["Cash", 15, 30],
    2: ["Card", 10, 20],
    3: ["Online Payment", 5, 15]
}

payment_wait_time = []
payment_time = []
order_wait_time = []
order_time = []

customer_data = []


def generate_customer(env, cashier, barista):
    while env.now < shop_uptime:
        yield env.timeout(random.randint(1, 20))
        env.process(customer(env, env.now, cashier, barista))



def customer(env, name, cashier, barista):
    print("Customer %s arrived at time %.1f" % (name, env.now))

    with cashier.request() as req:
        start_cq = env.now
        yield req
        payment_wait_time.append(env.now - start_cq)

        menu_item = random.randint(1, 6)
        payment_type = random.randint(1, 2)
        time_to_order = random.randint(payment_options[payment_type][1], payment_options[payment_type][2])
        payment_name = payment_options[payment_type][0]

        yield env.timeout(time_to_order)
        print(">>> Customer %s finished paying by %s in %.1f seconds" % (name, payment_name, env.now - start_cq))
        payment_time.append(env.now - start_cq)

    with barista.request() as req:
        start_bq = env.now
        yield req
        order_wait_time.append(env.now - start_bq)

        time_to_prepare = random.randint(menu[menu_item][1], menu[menu_item][2])
        item_name = menu[menu_item][0]

        yield env.timeout(time_to_prepare)
        print(">> >> >> Customer %s served %s in %.1f seconds" % (name, item_name, env.now - start_cq))
        order_time.append(env.now - start_cq)

    customer_data.append((
        payment_wait_time[-1],  # Last added payment wait time
        payment_time[-1],       # Last added payment time
        order_wait_time[-1],    # Last added order wait time
        order_time[-1]          # Last added order time
    ))


env.process(generate_customer(env, cashier, barista))

print("WITH %s CASHIERS AND %s BARISTAS AND %s SERIALLY ARRIVING CUSTOMERS..." % (cashier_count, barista_count, customer_count))

env.run(until=shop_uptime)
# Out:
# WITH 10 CASHIERS AND 20 BARISTAS AND 1000 SERIALLY ARRIVING CUSTOMERS...
# Customer 11 arrived at time 11.0
# Customer 27 arrived at time 27.0
# >>> Customer 11 finished paying by Cash in 20.0 seconds
# Customer 31 arrived at time 31.0
# Customer 44 arrived at time 44.0
# >>> Customer 27 finished paying by Card in 19.0 seconds
# >>> Customer 31 finished paying by Cash in 16.0 seconds
# >> >> >> Customer 11 served Cold Brew in 38.0 seconds
# Customer 56 arrived at time 56.0
# Customer 65 arrived at time 65.0
# >>> Customer 44 finished paying by Cash in 27.0 seconds
# >>> Customer 56 finished paying by Cash in 16.0 seconds
# >> >> >> Customer 31 served Mocha in 52.0 seconds
# Customer 85 arrived at time 85.0
# >>> Customer 65 finished paying by Card in 20.0 seconds
# >> >> >> Customer 56 served Cold Brew in 29.0 seconds
# >> >> >> Customer 27 served Mocha in 63.0 seconds
# Customer 97 arrived at time 97.0
# >>> Customer 85 finished paying by Card in 19.0 seconds
# >> >> >> Customer 44 served Espresso in 61.0 seconds
# Customer 108 arrived at time 108.0
# >>> Customer 97 finished paying by Card in 13.0 seconds
# >> >> >> Customer 85 served Cold Brew in 35.0 seconds
# >>> Customer 108 finished paying by Card in 13.0 seconds
# >> >> >> Customer 97 served Regular Coffee in 25.0 seconds
# Customer 125 arrived at time 125.0
# >> >> >> Customer 65 served Frappe in 71.0 seconds
# >> >> >> Customer 108 served Regular Coffee in 28.0 seconds
# Customer 140 arrived at time 140.0
# Customer 147 arrived at time 147.0
# Customer 149 arrived at time 149.0
# >>> Customer 125 finished paying by Cash in 30.0 seconds
# >>> Customer 140 finished paying by Cash in 16.0 seconds
# Customer 162 arrived at time 162.0
# >>> Customer 149 finished paying by Card in 13.0 seconds
# >>> Customer 147 finished paying by Cash in 17.0 seconds
# Customer 167 arrived at time 167.0
# >> >> >> Customer 149 served Cold Brew in 23.0 seconds
# >>> Customer 162 finished paying by Card in 14.0 seconds
# >>> Customer 167 finished paying by Card in 10.0 seconds
# Customer 182 arrived at time 182.0
# >> >> >> Customer 162 served Regular Coffee in 24.0 seconds
# >> >> >> Customer 140 served Mocha in 52.0 seconds
# >> >> >> Customer 125 served Mocha in 68.0 seconds
# Customer 201 arrived at time 201.0
# >> >> >> Customer 167 served Espresso in 35.0 seconds
# >>> Customer 182 finished paying by Card in 20.0 seconds
# Customer 202 arrived at time 202.0
# Customer 205 arrived at time 205.0
# >>> Customer 201 finished paying by Card in 12.0 seconds
# Customer 216 arrived at time 216.0
# >>> Customer 202 finished paying by Card in 18.0 seconds
# >>> Customer 205 finished paying by Card in 15.0 seconds
# >> >> >> Customer 147 served Frappe in 74.0 seconds
# >> >> >> Customer 182 served Cold Brew in 40.0 seconds
# >>> Customer 216 finished paying by Card in 14.0 seconds
# Customer 231 arrived at time 231.0
# >> >> >> Customer 202 served Regular Coffee in 32.0 seconds
# Customer 237 arrived at time 237.0
# >>> Customer 231 finished paying by Cash in 17.0 seconds
# >> >> >> Customer 205 served Latte in 45.0 seconds
# >> >> >> Customer 201 served Latte in 54.0 seconds
# Customer 255 arrived at time 255.0
# >>> Customer 237 finished paying by Cash in 18.0 seconds
# Customer 259 arrived at time 259.0
# >> >> >> Customer 216 served Latte in 50.0 seconds
# >>> Customer 255 finished paying by Card in 17.0 seconds
# >> >> >> Customer 231 served Espresso in 42.0 seconds
# Customer 273 arrived at time 273.0
# Customer 276 arrived at time 276.0
# >>> Customer 259 finished paying by Cash in 24.0 seconds
# >>> Customer 273 finished paying by Card in 10.0 seconds
# >> >> >> Customer 237 served Espresso in 48.0 seconds
# Customer 293 arrived at time 293.0
# >>> Customer 276 finished paying by Cash in 19.0 seconds
# Customer 295 arrived at time 295.0
# >> >> >> Customer 259 served Cold Brew in 41.0 seconds
# Customer 304 arrived at time 304.0
# Customer 312 arrived at time 312.0
# >>> Customer 295 finished paying by Cash in 18.0 seconds
# >> >> >> Customer 255 served Latte in 59.0 seconds
# >>> Customer 293 finished paying by Cash in 28.0 seconds
# >> >> >> Customer 273 served Latte in 49.0 seconds
# >>> Customer 304 finished paying by Cash in 20.0 seconds
# >> >> >> Customer 295 served Regular Coffee in 30.0 seconds
# Customer 331 arrived at time 331.0
# >> >> >> Customer 276 served Mocha in 58.0 seconds
# >>> Customer 312 finished paying by Cash in 27.0 seconds
# Customer 350 arrived at time 350.0
# >> >> >> Customer 293 served Espresso in 59.0 seconds
# >>> Customer 331 finished paying by Cash in 23.0 seconds
# Customer 358 arrived at time 358.0
# >> >> >> Customer 331 served Regular Coffee in 33.0 seconds
# >>> Customer 358 finished paying by Card in 12.0 seconds
# Customer 373 arrived at time 373.0
# >>> Customer 350 finished paying by Cash in 26.0 seconds
# >> >> >> Customer 304 served Frappe in 75.0 seconds
# Customer 380 arrived at time 380.0
# >>> Customer 373 finished paying by Card in 18.0 seconds
# >>> Customer 380 finished paying by Card in 16.0 seconds
# >> >> >> Customer 312 served Frappe in 86.0 seconds
# Customer 398 arrived at time 398.0
# Customer 408 arrived at time 408.0
# >> >> >> Customer 380 served Cold Brew in 29.0 seconds
# Customer 409 arrived at time 409.0
# >> >> >> Customer 350 served Espresso in 61.0 seconds
# Customer 418 arrived at time 418.0
# >> >> >> Customer 358 served Frappe in 63.0 seconds
# >> >> >> Customer 373 served Espresso in 51.0 seconds
# >>> Customer 408 finished paying by Card in 16.0 seconds
# >>> Customer 398 finished paying by Cash in 29.0 seconds
# >>> Customer 409 finished paying by Cash in 27.0 seconds
# Customer 438 arrived at time 438.0
# >>> Customer 418 finished paying by Cash in 20.0 seconds
# >> >> >> Customer 408 served Cold Brew in 32.0 seconds
# >> >> >> Customer 398 served Cold Brew in 42.0 seconds
# Customer 455 arrived at time 455.0
# >>> Customer 438 finished paying by Card in 17.0 seconds
# Customer 460 arrived at time 460.0
# Customer 474 arrived at time 474.0
# >>> Customer 455 finished paying by Cash in 20.0 seconds
# >> >> >> Customer 438 served Mocha in 49.0 seconds
# >>> Customer 460 finished paying by Cash in 27.0 seconds
# Customer 491 arrived at time 491.0
# >>> Customer 474 finished paying by Card in 18.0 seconds
# >> >> >> Customer 418 served Frappe in 75.0 seconds
# Customer 493 arrived at time 493.0
# Customer 494 arrived at time 494.0
# >> >> >> Customer 409 served Frappe in 86.0 seconds
# >> >> >> Customer 460 served Regular Coffee in 37.0 seconds
# >>> Customer 491 finished paying by Card in 15.0 seconds
# Customer 511 arrived at time 511.0
# >>> Customer 494 finished paying by Card in 17.0 seconds
# >>> Customer 493 finished paying by Cash in 24.0 seconds
# >> >> >> Customer 491 served Regular Coffee in 26.0 seconds
# >> >> >> Customer 474 served Mocha in 51.0 seconds
# Customer 525 arrived at time 525.0
# >>> Customer 511 finished paying by Card in 14.0 seconds
# >> >> >> Customer 494 served Cold Brew in 31.0 seconds
# >> >> >> Customer 493 served Regular Coffee in 35.0 seconds
# Customer 536 arrived at time 536.0
# >> >> >> Customer 455 served Frappe in 85.0 seconds
# >>> Customer 536 finished paying by Card in 11.0 seconds
# >>> Customer 525 finished paying by Cash in 26.0 seconds
# Customer 554 arrived at time 554.0
# Customer 561 arrived at time 561.0
# >> >> >> Customer 525 served Cold Brew in 38.0 seconds
# Customer 563 arrived at time 563.0
# Customer 564 arrived at time 564.0
# >> >> >> Customer 511 served Latte in 55.0 seconds
# >>> Customer 554 finished paying by Card in 13.0 seconds
# >>> Customer 561 finished paying by Card in 17.0 seconds
# >>> Customer 563 finished paying by Cash in 16.0 seconds
# Customer 579 arrived at time 579.0
# >> >> >> Customer 536 served Mocha in 53.0 seconds
# >>> Customer 579 finished paying by Card in 11.0 seconds
# >> >> >> Customer 561 served Cold Brew in 31.0 seconds
# Customer 593 arrived at time 593.0
# >>> Customer 564 finished paying by Cash in 30.0 seconds
# >> >> >> Customer 563 served Cold Brew in 33.0 seconds
# Customer 603 arrived at time 603.0
# >>> Customer 593 finished paying by Card in 10.0 seconds
# >> >> >> Customer 554 served Latte in 50.0 seconds
# Customer 609 arrived at time 609.0
# Customer 619 arrived at time 619.0
# >> >> >> Customer 593 served Espresso in 33.0 seconds
# >>> Customer 603 finished paying by Cash in 24.0 seconds
# >> >> >> Customer 579 served Latte in 50.0 seconds
# >>> Customer 619 finished paying by Card in 10.0 seconds
# >> >> >> Customer 564 served Latte in 66.0 seconds
# >>> Customer 609 finished paying by Cash in 28.0 seconds
# >> >> >> Customer 603 served Cold Brew in 35.0 seconds
# Customer 639 arrived at time 639.0
# >> >> >> Customer 619 served Regular Coffee in 23.0 seconds
# >>> Customer 639 finished paying by Card in 11.0 seconds
# Customer 656 arrived at time 656.0
# >> >> >> Customer 639 served Regular Coffee in 23.0 seconds
# >> >> >> Customer 609 served Mocha in 58.0 seconds
# >>> Customer 656 finished paying by Card in 14.0 seconds
# Customer 674 arrived at time 674.0
# Customer 676 arrived at time 676.0
# >> >> >> Customer 656 served Cold Brew in 25.0 seconds
# Customer 691 arrived at time 691.0
# >>> Customer 674 finished paying by Cash in 22.0 seconds
# >>> Customer 691 finished paying by Card in 12.0 seconds
# >>> Customer 676 finished paying by Cash in 30.0 seconds
# Customer 706 arrived at time 706.0
# Customer 707 arrived at time 707.0
# >> >> >> Customer 674 served Cold Brew in 34.0 seconds
# Customer 711 arrived at time 711.0
# Customer 714 arrived at time 714.0
# >>> Customer 707 finished paying by Card in 12.0 seconds
# >>> Customer 706 finished paying by Cash in 15.0 seconds
# Customer 728 arrived at time 728.0
# Customer 733 arrived at time 733.0
# >> >> >> Customer 676 served Espresso in 58.0 seconds
# >> >> >> Customer 691 served Latte in 44.0 seconds
# >>> Customer 711 finished paying by Cash in 25.0 seconds
# >> >> >> Customer 706 served Regular Coffee in 30.0 seconds
# >>> Customer 728 finished paying by Card in 11.0 seconds
# Customer 742 arrived at time 742.0
# >>> Customer 714 finished paying by Cash in 29.0 seconds
# >>> Customer 733 finished paying by Card in 13.0 seconds
# >> >> >> Customer 711 served Regular Coffee in 36.0 seconds
# >>> Customer 742 finished paying by Card in 12.0 seconds
# >> >> >> Customer 707 served Latte in 48.0 seconds
# >> >> >> Customer 714 served Regular Coffee in 41.0 seconds
# Customer 757 arrived at time 757.0
# Customer 760 arrived at time 760.0
# >> >> >> Customer 733 served Cold Brew in 28.0 seconds
# >>> Customer 757 finished paying by Card in 10.0 seconds
# Customer 770 arrived at time 770.0
# >>> Customer 760 finished paying by Card in 10.0 seconds
# Customer 771 arrived at time 771.0
# >> >> >> Customer 760 served Regular Coffee in 23.0 seconds
# >>> Customer 771 finished paying by Card in 12.0 seconds
# Customer 785 arrived at time 785.0
# Customer 786 arrived at time 786.0
# >>> Customer 770 finished paying by Cash in 26.0 seconds
# Customer 798 arrived at time 798.0
# >> >> >> Customer 742 served Mocha in 57.0 seconds
# >>> Customer 785 finished paying by Card in 15.0 seconds
# >> >> >> Customer 728 served Frappe in 81.0 seconds
# >>> Customer 798 finished paying by Card in 15.0 seconds
# >>> Customer 786 finished paying by Cash in 28.0 seconds
# >> >> >> Customer 771 served Espresso in 44.0 seconds
# Customer 818 arrived at time 818.0
# >> >> >> Customer 757 served Frappe in 64.0 seconds
# >> >> >> Customer 770 served Espresso in 54.0 seconds
# >> >> >> Customer 798 served Regular Coffee in 27.0 seconds
# >> >> >> Customer 785 served Espresso in 43.0 seconds
# >>> Customer 818 finished paying by Card in 12.0 seconds
# Customer 836 arrived at time 836.0
# >> >> >> Customer 786 served Espresso in 55.0 seconds
# Customer 847 arrived at time 847.0
# Customer 850 arrived at time 850.0
# >>> Customer 836 finished paying by Cash in 17.0 seconds
# >> >> >> Customer 818 served Espresso in 37.0 seconds
# >>> Customer 850 finished paying by Card in 14.0 seconds
# Customer 865 arrived at time 865.0
# >>> Customer 847 finished paying by Cash in 25.0 seconds
# Customer 880 arrived at time 880.0
# Customer 890 arrived at time 890.0
# >> >> >> Customer 850 served Espresso in 41.0 seconds
# >>> Customer 865 finished paying by Cash in 26.0 seconds

# %%
print("Average wait time in payment queue: %.1f seconds." % (numpy.mean(payment_wait_time)))
print("Average time until making the payment: %.1f seconds." % (numpy.mean(payment_time)))
print("Average wait time in order queue: %.1f seconds." % (numpy.mean(order_wait_time)))
print("Average time until order is serviced: %.1f seconds." % (numpy.mean(order_time)))
print("Total simulation time: %.1f minutes." % env.now)
# Out:
# Average wait time in payment queue: 0.0 seconds.
# Average time until making the payment: 18.2 seconds.
# Average wait time in order queue: 0.0 seconds.
# Average time until order is serviced: 46.2 seconds.
# Total simulation time: 900.0 minutes.

# %%
df = pd.DataFrame(customer_data, columns=["Payment Wait Time", "Payment Time", "Order Wait Time", "Order Time"])

# Display first 10 rows
df.head(10)
# Out:
#    Payment Wait Time  Payment Time  Order Wait Time  Order Time
# 0                  0            16                0          38
# 1                  0            16                0          52
# 2                  0            20                0          29
# 3                  0            20                0          63
# 4                  0            19                0          61
# 5                  0            13                0          35
# 6                  0            13                0          25
# 7                  0            13                0          71
# 8                  0            13                0          28
# 9                  0            17                0          23
