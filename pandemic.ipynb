# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jun  7 23:07:17 2021

@author: User
"""

import turtle
import random
import math

odd_number_as_sqrt_of_population = 15
#If we use an odd number, the balls will not go to the edge with social distancing and every position will be used as you see

infection_prob = 100
#infection_prob = the probability of one infecting another when they collide
population = odd_number_as_sqrt_of_population**2
#The total population is the square root of the variable odd_number_as_sqrt_of_population
recovery_time = 100
#the recovery time stand for how long it takes every infected ball/person to recover and no longer be contagious (when they're no longer contagious, they turn gray)
social_distancing = False
start_sd = 30
#start_sd = the amount of people that have to be infected before social distancing kicks in, some people get infected while moving to the social distancing spot
sd_p = 100
#sd_p is the percentage of people that participate in social distancing
quarantaine_on = True
time_until_q = 3000
#we can even turn on social distancing and quarantaine on the same time...

wn = turtle.Screen()
wn.bgcolor('black')
wn.title('Epidemic simulator')
wn.tracer(0)
#the part above creates the screen that pops up when we run the code. To make everything work, allways use wn.mainloop() at the end.

pen = turtle.Turtle()
pen.speed(0)
pen.color('white')
pen.penup()
pen.setposition(-200,-200)
pen.pendown()
pen.pensize(3)
for i in range(4):
    pen.fd(400)
    pen.lt(90)
pen.hideturtle()
#this part creates the white square

time = 0
balls = []
#balls is the list containing all the balls
infected = []
#the list infected contains all balls that got infected (red and gray).
time_infected = {}
tot_inf = []
#same as infected, without duplicates
recovered = []
#recovered contains all balls that are recovered (gray).
closest_ball = []
spaces_x = []
spaces_y = []
coordinates = []
#coordinates contains all coordinates available for the social distancing

for i in range(-200,201):
    if i%int(400/math.sqrt(population)) == 0: #this is a calculation I created to make sure that more coordinates are created with a larger population
        #the weird population value, using the square of an odd number is part of this calculation.
        spaces_x.append(i)
        spaces_y.append(i)

for x in spaces_x:
    for y in spaces_y:
        coordinate = [x,y]
        coordinates.append(coordinate)

for _ in range(population):
    balls.append(turtle.Turtle())
    #this part appends a turtle to the list balls

for ball in balls:
    ball.shape('circle')
    ball.shapesize(0.45,0.45)
    ball.color('#4183C4')
    ball.penup()
    ball.speed(0)
    x = random.randint(-190, 190)
    y = random.randint(-190, 190)
    ball.goto(x, y)
    ball.dx = random.choice([-3,-2.75,-2.5,-2.25,-2,-1.75,-1.5,-1.25,-1,-0.75,-0.5,-0.25,3,2.75,2.5,2.25,2,1.75,1.5,1.25,1,0.75,0.5,0.25])
    ball.dy = random.choice([-3,-2.75,-2.5,-2.25,-2,-1.75,-1.5,-1.25,-1,-0.75,-0.5,-0.25,3,2.75,2.5,2.25,2,1.75,1.5,1.25,1,0.75,0.5,0.25])
    #here we add some information to that turtle, shape, coordinates, color, size and its dx and dy, the dx and dy are the changes in x and y for every ball
    # together they are the speed and direction of every ball. They are chosen randomly from the list using random.

    #Now we want 1 ball to become red (infected), preferably the one closest to the coordinate (0,0)

infections = {i : 0 for i in balls}
#infections is a dictionary containing every ball from balls and setting its value to 0


def closest_to_O():
    global closest_ball

    min_dist = 0
    for x in range(len(balls)):

            xdist = balls[x].xcor()
            ydist = balls[x].ycor()
            dist_squared = xdist*xdist + ydist*ydist
            if len(closest_ball) == 0:
                closest_ball.append(balls[x])
                min_dist = dist_squared
            elif dist_squared < min_dist:
                closest_ball.clear()
                closest_ball.append(balls[x])
                min_dist = dist_squared
    #this function checks which ball is closest to the coordinate (0,0) and appends it to the list closest_ball
    #so the list closest_ball has length 1 and contains only the ball closest to (0,0)


def mark_infected():
    global closest_ball

    if closest_ball[0] not in recovered:
        closest_ball[0].color('red')
        infected.append(closest_ball[0])
    #this function marks the ball closest to (0,0) as infected by adding it to the list infected and making its color red.


def collide():
    global infection_prob

    for i in range(len(balls)):

        for x in range(i+1, len(balls)):

            xdist = balls[i].xcor() - balls[x].xcor()
            ydist = balls[i].ycor() - balls[x].ycor()
            dist_squared = xdist*xdist + ydist*ydist
            if dist_squared < 125:
                if balls[i] not in recovered and balls[x] not in recovered:
                # I added this if statement because recovered balls can not infect other balls
                    if balls[i] in infected and balls[x] not in infected and random.randint(0,100) in range(0, infection_prob + 1):
                        balls[x].color('red')
                        infected.append(balls[x])
                    elif balls[i] not in infected and balls[x] in infected and random.randint(0,100) in range(0, infection_prob + 1):
                        balls[i].color('red')
                        infected.append(balls[i])
                        #the balls turn red and are added to the list infected
    # the collide function check if balls collide and infects uninfected balls when they collide with an infected one.


def recovered_():

    global population, recovery_time

    for i in range(len(balls)):
        if balls[i] in infected:
            infections[balls[i]] += 1
            #everytime that the computer runs trough this for loop, the value of the ball in infections increases by 1
            if balls[i] not in recovered:
                if infections[balls[i]] >= recovery_time:
                    balls[i].color('gray')
                    recovered.append(balls[i])
    # here we see that recovered balls turn gray and are added to the list recovered.

def social_dist():

    min_dist = 0
    closest_dist = []

    for i in range(len(balls)):

        if balls[i].xcor() > -250:
        #this line above is only for quarantaine mode

            if random.randint(0,100) in range(0, sd_p + 1):

                for c in coordinates:

                    xdist = balls[i].xcor() - c[0]
                    ydist = balls[i].ycor() - c[1]
                    dist_squared = xdist*xdist + ydist*ydist
                    #dist_squared is the square of the distance to the coordinate in coordinates
                    if len(closest_dist) == 0:
                        closest_dist = c
                        min_dist = dist_squared
                    elif dist_squared < min_dist:
                        closest_dist = c
                        min_dist = dist_squared
                    #It looks for the closest coordinate in coordinates to the ball.

                if len(coordinates) > 0:
                    try:
                        coordinates.remove(closest_dist)
                        #this removes the coordinate that is already chosen by a ball from coordinates to make sure every coordinate gets only used once.
                    except:
                        coordinates.remove(coordinates[0])
                    balls[i].dx = 0
                    balls[i].dy = 0
                    balls[i].goto(closest_dist[0], closest_dist[1])

                closest_dist.clear()

def quarantaine():
    global time_infected


    room = turtle.Turtle()
    room.speed(0)
    room.color('white')
    room.penup()
    room.setposition(-360,-210)
    room.pendown()
    room.pensize(3)
    for i in range(4):
        room.fd(120)
        room.lt(90)
    room.hideturtle()
    #this draws a room for infected people

    for i in infected:

        if i.xcor() >= -350 and i.xcor() <= -250 and i.ycor() >= -200 and i.ycor() <= -100:
            i.dx = 0
            i.dy = 0
            i.setposition(random.randint(-350,-250), random.randint(-200,-100))
            time_infected[i] = 0

        elif i not in time_infected.keys():
            time_infected[i] = time
            #this makes the value of an infected ball in the dictionary time_infected, the time when the ball gets infected
        elif i in time_infected.keys():
            if time - time_infected[i] >= time_until_q and i.xcor() > -250:
                #if the time that they are infected is larger or equal to the time until quarantaine (time_until_q)
                dx_q = (random.randint(-275,-225) - i.xcor())*(-1)
                dy_q = random.randint(-175,-125) - i.ycor()
                try:
                    rc = dy_q/dx_q
                    if -4 < rc < 4:
                        i.dx = -10
                        i.dy = 10 * rc
                    else:
                        i.dx = 0
                        i.dy = 0
                        i.goto(random.randint(-350,-250), random.randint(-200,-100))
                        time_infected[i] = 0
                    #the direction and speed of the ball is set to go to the created quarantaine room
                except:
                    i.dx = 0
                    i.dy = 0
                    i.goto(random.randint(-350,-250), random.randint(-200,-100))
                    time_infected[i] = 0
                time_infected[i] = 0



closest_to_O()
mark_infected()

#this part makes every ball move and has almost all functions in it to make sure they're constantly checked.
while True:

    wn.update()
    #this updates the screen every time

    for ball in balls:

        time += 1

        ball.sety(ball.ycor() + ball.dy)
        ball.setx(ball.xcor() + ball.dx)
        #the two lines above move the balls

        if ball.xcor() < -195 or ball.xcor() > 195:
            ball.dx *= -1

        if ball.ycor() < -195 or ball.ycor() > 195:
            ball.dy *= -1
            # both of the if statements make sure that the balls change direction when they hit the edge of the white square

    collide()
    recovered_()

    if social_distancing and len(tot_inf) >= start_sd:
        #this only allows social distancing to happen if social_distancing is True and there are enough people infected to start social distancing.
        social_dist()

    if quarantaine_on:
        quarantaine()

    for i in infected:
        if i not in tot_inf:
            tot_inf.append(i)
        #the list tot_inf contains every element in infected, without duplicates.


    if len(recovered) < len(tot_inf):
        print('\n', 'Percentage infected:', len(tot_inf)/population * 100, '\n',
        'Infected people:' , len(tot_inf), '\n' , 'Recovered people:', len(recovered), '\n', 'Time:' , time , 'minutes')
        #this prints information about the simulation while there are still unrecovered infected balls/people.
    if len(recovered) == len(tot_inf) and len(recovered) > 0:
        message = 'Percentage infected: '+str(len(tot_inf)/population * 100)+'\n'+'Infected people: '+str(len(tot_inf))+'\n'+'Recovered people: '+str(len(recovered))+'\n'+'Time: '+str(time)+' minutes'
        end_message = turtle.Turtle()
        end_message.speed(0)
        end_message.color('white')
        end_message.penup()
        end_message.setposition(-190,205)
        end_message.pendown()
        end_message.pensize(10)
        end_message.write(message, font = ('style', 18, 'bold'))
        end_message.hideturtle()
        break
        #This shows the same statistics as above at the end of the simulation (when all the infected people are recovered). It also stops the while loop at that point


wn.mainloop()
# Out:
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 225 minutes
#
#  Percentage infected: 0.4444444444444444
#  Infected people: 1
#  Recovered people: 0
#  Time: 450 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 675 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 900 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 1125 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 1350 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 1575 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 1800 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 2025 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 2250 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 2475 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 2700 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 2925 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 3150 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 3375 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 3600 minutes
#
#  Percentage infected: 1.3333333333333335
#  Infected people: 3
#  Recovered people: 0
#  Time: 3825 minutes
#
#  Percentage infected: 1.7777777777777777
#  Infected people: 4
#  Recovered people: 0
#  Time: 4050 minutes
#
#  Percentage infected: 3.111111111111111
#  Infected people: 7
#  Recovered people: 0
#  Time: 4275 minutes
#
#  Percentage infected: 4.0
#  Infected people: 9
#  Recovered people: 0
#  Time: 4500 minutes
#
#  Percentage infected: 4.444444444444445
#  Infected people: 10
#  Recovered people: 0
#  Time: 4725 minutes
#
#  Percentage infected: 5.333333333333334
#  Infected people: 12
#  Recovered people: 0
#  Time: 4950 minutes
#
#  Percentage infected: 6.222222222222222
#  Infected people: 14
#  Recovered people: 0
#  Time: 5175 minutes
#
#  Percentage infected: 7.111111111111111
#  Infected people: 16
#  Recovered people: 0
#  Time: 5400 minutes
#
#  Percentage infected: 8.0
#  Infected people: 18
#  Recovered people: 0
#  Time: 5625 minutes
#
#  Percentage infected: 8.0
#  Infected people: 18
#  Recovered people: 0
#  Time: 5850 minutes
#
#  Percentage infected: 8.444444444444445
#  Infected people: 19
#  Recovered people: 0
#  Time: 6075 minutes
#
#  Percentage infected: 8.88888888888889
#  Infected people: 20
#  Recovered people: 0
#  Time: 6300 minutes
#
#  Percentage infected: 9.777777777777779
#  Infected people: 22
#  Recovered people: 0
#  Time: 6525 minutes
#
#  Percentage infected: 10.222222222222223
#  Infected people: 23
#  Recovered people: 0
#  Time: 6750 minutes
#
#  Percentage infected: 11.11111111111111
#  Infected people: 25
#  Recovered people: 0
#  Time: 6975 minutes
#
#  Percentage infected: 12.444444444444445
#  Infected people: 28
#  Recovered people: 0
#  Time: 7200 minutes
#
#  Percentage infected: 12.444444444444445
#  Infected people: 28
#  Recovered people: 0
#  Time: 7425 minutes
#
#  Percentage infected: 12.88888888888889
#  Infected people: 29
#  Recovered people: 0
#  Time: 7650 minutes
#
#  Percentage infected: 13.333333333333334
#  Infected people: 30
#  Recovered people: 0
#  Time: 7875 minutes
#
#  Percentage infected: 14.222222222222221
#  Infected people: 32
#  Recovered people: 0
#  Time: 8100 minutes
#
#  Percentage infected: 16.444444444444446
#  Infected people: 37
#  Recovered people: 0
#  Time: 8325 minutes
#
#  Percentage infected: 16.88888888888889
#  Infected people: 38
#  Recovered people: 0
#  Time: 8550 minutes
#
#  Percentage infected: 18.666666666666668
#  Infected people: 42
#  Recovered people: 0
#  Time: 8775 minutes
#
#  Percentage infected: 19.11111111111111
#  Infected people: 43
#  Recovered people: 0
#  Time: 9000 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 9225 minutes
#
#  Percentage infected: 20.444444444444446
#  Infected people: 46
#  Recovered people: 0
#  Time: 9450 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 0
#  Time: 9675 minutes
#
#  Percentage infected: 21.333333333333336
#  Infected people: 48
#  Recovered people: 0
#  Time: 9900 minutes
#
#  Percentage infected: 22.22222222222222
#  Infected people: 50
#  Recovered people: 0
#  Time: 10125 minutes
#
#  Percentage infected: 23.11111111111111
#  Infected people: 52
#  Recovered people: 0
#  Time: 10350 minutes
#
#  Percentage infected: 23.555555555555554
#  Infected people: 53
#  Recovered people: 0
#  Time: 10575 minutes
#
#  Percentage infected: 24.0
#  Infected people: 54
#  Recovered people: 0
#  Time: 10800 minutes
#
#  Percentage infected: 24.0
#  Infected people: 54
#  Recovered people: 0
#  Time: 11025 minutes
#
#  Percentage infected: 24.444444444444443
#  Infected people: 55
#  Recovered people: 0
#  Time: 11250 minutes
#
#  Percentage infected: 24.88888888888889
#  Infected people: 56
#  Recovered people: 0
#  Time: 11475 minutes
#
#  Percentage infected: 24.88888888888889
#  Infected people: 56
#  Recovered people: 0
#  Time: 11700 minutes
#
#  Percentage infected: 24.88888888888889
#  Infected people: 56
#  Recovered people: 0
#  Time: 11925 minutes
#
#  Percentage infected: 25.77777777777778
#  Infected people: 58
#  Recovered people: 0
#  Time: 12150 minutes
#
#  Percentage infected: 26.666666666666668
#  Infected people: 60
#  Recovered people: 0
#  Time: 12375 minutes
#
#  Percentage infected: 27.111111111111114
#  Infected people: 61
#  Recovered people: 0
#  Time: 12600 minutes
#
#  Percentage infected: 27.111111111111114
#  Infected people: 61
#  Recovered people: 0
#  Time: 12825 minutes
#
#  Percentage infected: 27.555555555555557
#  Infected people: 62
#  Recovered people: 0
#  Time: 13050 minutes
#
#  Percentage infected: 27.555555555555557
#  Infected people: 62
#  Recovered people: 0
#  Time: 13275 minutes
#
#  Percentage infected: 27.555555555555557
#  Infected people: 62
#  Recovered people: 0
#  Time: 13500 minutes
#
#  Percentage infected: 28.000000000000004
#  Infected people: 63
#  Recovered people: 0
#  Time: 13725 minutes
#
#  Percentage infected: 28.444444444444443
#  Infected people: 64
#  Recovered people: 0
#  Time: 13950 minutes
#
#  Percentage infected: 28.888888888888886
#  Infected people: 65
#  Recovered people: 0
#  Time: 14175 minutes
#
#  Percentage infected: 28.888888888888886
#  Infected people: 65
#  Recovered people: 0
#  Time: 14400 minutes
#
#  Percentage infected: 28.888888888888886
#  Infected people: 65
#  Recovered people: 0
#  Time: 14625 minutes
#
#  Percentage infected: 29.333333333333332
#  Infected people: 66
#  Recovered people: 0
#  Time: 14850 minutes
#
#  Percentage infected: 29.333333333333332
#  Infected people: 66
#  Recovered people: 0
#  Time: 15075 minutes
#
#  Percentage infected: 29.333333333333332
#  Infected people: 66
#  Recovered people: 0
#  Time: 15300 minutes
#
#  Percentage infected: 30.666666666666664
#  Infected people: 69
#  Recovered people: 0
#  Time: 15525 minutes
#
#  Percentage infected: 30.666666666666664
#  Infected people: 69
#  Recovered people: 0
#  Time: 15750 minutes
#
#  Percentage infected: 30.666666666666664
#  Infected people: 69
#  Recovered people: 0
#  Time: 15975 minutes
#
#  Percentage infected: 30.666666666666664
#  Infected people: 69
#  Recovered people: 0
#  Time: 16200 minutes
#
#  Percentage infected: 31.11111111111111
#  Infected people: 70
#  Recovered people: 0
#  Time: 16425 minutes
#
#  Percentage infected: 31.11111111111111
#  Infected people: 70
#  Recovered people: 0
#  Time: 16650 minutes
#
#  Percentage infected: 31.555555555555554
#  Infected people: 71
#  Recovered people: 0
#  Time: 16875 minutes
#
#  Percentage infected: 32.0
#  Infected people: 72
#  Recovered people: 0
#  Time: 17100 minutes
#
#  Percentage infected: 32.0
#  Infected people: 72
#  Recovered people: 0
#  Time: 17325 minutes
#
#  Percentage infected: 32.44444444444444
#  Infected people: 73
#  Recovered people: 0
#  Time: 17550 minutes
#
#  Percentage infected: 32.88888888888889
#  Infected people: 74
#  Recovered people: 0
#  Time: 17775 minutes
#
#  Percentage infected: 33.33333333333333
#  Infected people: 75
#  Recovered people: 0
#  Time: 18000 minutes
#
#  Percentage infected: 33.77777777777778
#  Infected people: 76
#  Recovered people: 0
#  Time: 18225 minutes
#
#  Percentage infected: 33.77777777777778
#  Infected people: 76
#  Recovered people: 0
#  Time: 18450 minutes
#
#  Percentage infected: 33.77777777777778
#  Infected people: 76
#  Recovered people: 0
#  Time: 18675 minutes
#
#  Percentage infected: 33.77777777777778
#  Infected people: 76
#  Recovered people: 0
#  Time: 18900 minutes
#
#  Percentage infected: 33.77777777777778
#  Infected people: 76
#  Recovered people: 0
#  Time: 19125 minutes
#
#  Percentage infected: 33.77777777777778
#  Infected people: 76
#  Recovered people: 0
#  Time: 19350 minutes
#
#  Percentage infected: 35.55555555555556
#  Infected people: 80
#  Recovered people: 0
#  Time: 19575 minutes
#
#  Percentage infected: 35.55555555555556
#  Infected people: 80
#  Recovered people: 0
#  Time: 19800 minutes
#
#  Percentage infected: 35.55555555555556
#  Infected people: 80
#  Recovered people: 0
#  Time: 20025 minutes
#
#  Percentage infected: 35.55555555555556
#  Infected people: 80
#  Recovered people: 0
#  Time: 20250 minutes
#
#  Percentage infected: 35.55555555555556
#  Infected people: 80
#  Recovered people: 0
#  Time: 20475 minutes
#
#  Percentage infected: 36.0
#  Infected people: 81
#  Recovered people: 0
#  Time: 20700 minutes
#
#  Percentage infected: 36.0
#  Infected people: 81
#  Recovered people: 0
#  Time: 20925 minutes
#
#  Percentage infected: 36.888888888888886
#  Infected people: 83
#  Recovered people: 0
#  Time: 21150 minutes
#
#  Percentage infected: 36.888888888888886
#  Infected people: 83
#  Recovered people: 0
#  Time: 21375 minutes
#
#  Percentage infected: 36.888888888888886
#  Infected people: 83
#  Recovered people: 0
#  Time: 21600 minutes
#
#  Percentage infected: 36.888888888888886
#  Infected people: 83
#  Recovered people: 0
#  Time: 21825 minutes
#
#  Percentage infected: 36.888888888888886
#  Infected people: 83
#  Recovered people: 0
#  Time: 22050 minutes
#
#  Percentage infected: 37.333333333333336
#  Infected people: 84
#  Recovered people: 0
#  Time: 22275 minutes
#
#  Percentage infected: 37.77777777777778
#  Infected people: 85
#  Recovered people: 1
#  Time: 22500 minutes
#
#  Percentage infected: 38.22222222222222
#  Infected people: 86
#  Recovered people: 1
#  Time: 22725 minutes
#
#  Percentage infected: 38.666666666666664
#  Infected people: 87
#  Recovered people: 3
#  Time: 22950 minutes
#
#  Percentage infected: 38.666666666666664
#  Infected people: 87
#  Recovered people: 3
#  Time: 23175 minutes
#
#  Percentage infected: 39.111111111111114
#  Infected people: 88
#  Recovered people: 3
#  Time: 23400 minutes
#
#  Percentage infected: 40.44444444444444
#  Infected people: 91
#  Recovered people: 3
#  Time: 23625 minutes
#
#  Percentage infected: 40.88888888888889
#  Infected people: 92
#  Recovered people: 3
#  Time: 23850 minutes
#
#  Percentage infected: 40.88888888888889
#  Infected people: 92
#  Recovered people: 3
#  Time: 24075 minutes
#
#  Percentage infected: 40.88888888888889
#  Infected people: 92
#  Recovered people: 3
#  Time: 24300 minutes
#
#  Percentage infected: 40.88888888888889
#  Infected people: 92
#  Recovered people: 3
#  Time: 24525 minutes
#
#  Percentage infected: 40.88888888888889
#  Infected people: 92
#  Recovered people: 3
#  Time: 24750 minutes
#
#  Percentage infected: 41.333333333333336
#  Infected people: 93
#  Recovered people: 3
#  Time: 24975 minutes
#
#  Percentage infected: 42.22222222222222
#  Infected people: 95
#  Recovered people: 3
#  Time: 25200 minutes
#
#  Percentage infected: 43.55555555555555
#  Infected people: 98
#  Recovered people: 3
#  Time: 25425 minutes
#
#  Percentage infected: 44.44444444444444
#  Infected people: 100
#  Recovered people: 3
#  Time: 25650 minutes
#
#  Percentage infected: 44.44444444444444
#  Infected people: 100
#  Recovered people: 3
#  Time: 25875 minutes
#
#  Percentage infected: 44.44444444444444
#  Infected people: 100
#  Recovered people: 3
#  Time: 26100 minutes
#
#  Percentage infected: 44.44444444444444
#  Infected people: 100
#  Recovered people: 4
#  Time: 26325 minutes
#
#  Percentage infected: 44.44444444444444
#  Infected people: 100
#  Recovered people: 7
#  Time: 26550 minutes
#
#  Percentage infected: 45.77777777777778
#  Infected people: 103
#  Recovered people: 9
#  Time: 26775 minutes
#
#  Percentage infected: 46.22222222222222
#  Infected people: 104
#  Recovered people: 10
#  Time: 27000 minutes
#
#  Percentage infected: 46.666666666666664
#  Infected people: 105
#  Recovered people: 12
#  Time: 27225 minutes
#
#  Percentage infected: 46.666666666666664
#  Infected people: 105
#  Recovered people: 14
#  Time: 27450 minutes
#
#  Percentage infected: 46.666666666666664
#  Infected people: 105
#  Recovered people: 16
#  Time: 27675 minutes
#
#  Percentage infected: 46.666666666666664
#  Infected people: 105
#  Recovered people: 18
#  Time: 27900 minutes
#
#  Percentage infected: 46.666666666666664
#  Infected people: 105
#  Recovered people: 18
#  Time: 28125 minutes
#
#  Percentage infected: 47.11111111111111
#  Infected people: 106
#  Recovered people: 19
#  Time: 28350 minutes
#
#  Percentage infected: 47.11111111111111
#  Infected people: 106
#  Recovered people: 20
#  Time: 28575 minutes
#
#  Percentage infected: 47.11111111111111
#  Infected people: 106
#  Recovered people: 22
#  Time: 28800 minutes
#
#  Percentage infected: 47.11111111111111
#  Infected people: 106
#  Recovered people: 23
#  Time: 29025 minutes
#
#  Percentage infected: 47.11111111111111
#  Infected people: 106
#  Recovered people: 25
#  Time: 29250 minutes
#
#  Percentage infected: 47.11111111111111
#  Infected people: 106
#  Recovered people: 28
#  Time: 29475 minutes
#
#  Percentage infected: 47.11111111111111
#  Infected people: 106
#  Recovered people: 28
#  Time: 29700 minutes
#
#  Percentage infected: 47.11111111111111
#  Infected people: 106
#  Recovered people: 29
#  Time: 29925 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 30
#  Time: 30150 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 32
#  Time: 30375 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 37
#  Time: 30600 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 38
#  Time: 30825 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 42
#  Time: 31050 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 43
#  Time: 31275 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 46
#  Time: 31500 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 46
#  Time: 31725 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 48
#  Time: 31950 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 48
#  Time: 32175 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 50
#  Time: 32400 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 52
#  Time: 32625 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 53
#  Time: 32850 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 54
#  Time: 33075 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 54
#  Time: 33300 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 55
#  Time: 33525 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 56
#  Time: 33750 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 56
#  Time: 33975 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 56
#  Time: 34200 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 58
#  Time: 34425 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 60
#  Time: 34650 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 61
#  Time: 34875 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 61
#  Time: 35100 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 62
#  Time: 35325 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 62
#  Time: 35550 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 62
#  Time: 35775 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 63
#  Time: 36000 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 64
#  Time: 36225 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 65
#  Time: 36450 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 65
#  Time: 36675 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 65
#  Time: 36900 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 66
#  Time: 37125 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 66
#  Time: 37350 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 66
#  Time: 37575 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 69
#  Time: 37800 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 69
#  Time: 38025 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 69
#  Time: 38250 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 69
#  Time: 38475 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 70
#  Time: 38700 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 70
#  Time: 38925 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 71
#  Time: 39150 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 72
#  Time: 39375 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 72
#  Time: 39600 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 73
#  Time: 39825 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 74
#  Time: 40050 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 75
#  Time: 40275 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 76
#  Time: 40500 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 76
#  Time: 40725 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 76
#  Time: 40950 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 76
#  Time: 41175 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 76
#  Time: 41400 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 76
#  Time: 41625 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 80
#  Time: 41850 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 80
#  Time: 42075 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 80
#  Time: 42300 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 80
#  Time: 42525 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 80
#  Time: 42750 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 81
#  Time: 42975 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 81
#  Time: 43200 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 83
#  Time: 43425 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 83
#  Time: 43650 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 83
#  Time: 43875 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 83
#  Time: 44100 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 83
#  Time: 44325 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 84
#  Time: 44550 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 85
#  Time: 44775 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 86
#  Time: 45000 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 87
#  Time: 45225 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 87
#  Time: 45450 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 88
#  Time: 45675 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 91
#  Time: 45900 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 92
#  Time: 46125 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 92
#  Time: 46350 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 92
#  Time: 46575 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 92
#  Time: 46800 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 92
#  Time: 47025 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 93
#  Time: 47250 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 95
#  Time: 47475 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 98
#  Time: 47700 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 100
#  Time: 47925 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 100
#  Time: 48150 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 100
#  Time: 48375 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 100
#  Time: 48600 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 100
#  Time: 48825 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 103
#  Time: 49050 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 104
#  Time: 49275 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 105
#  Time: 49500 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 105
#  Time: 49725 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 105
#  Time: 49950 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 105
#  Time: 50175 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 105
#  Time: 50400 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 106
#  Time: 50625 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 106
#  Time: 50850 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 106
#  Time: 51075 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 106
#  Time: 51300 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 106
#  Time: 51525 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 106
#  Time: 51750 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 106
#  Time: 51975 minutes
#
#  Percentage infected: 48.0
#  Infected people: 108
#  Recovered people: 106
#  Time: 52200 minutes
